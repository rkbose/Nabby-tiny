# %%
import matplotlib.pyplot as plt
import numpy as np
pi = 3.1415279

x = np.linspace(0,4*pi,1000)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(10*x))
plt.plot(x, np.cos(10*x)*np.sin(x)+2)
plt.grid()
plt.show()
